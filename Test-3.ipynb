# %%
# print("Hello")



# Your last C/C++ code is saved below:
# #include <iostream>
# using namespace std;

# int main() {
# 	cout<<"Hello";
# 	return 0;
# }

#Given an array [1,2,3,1,2,3,4]. Find the one that is not duplicate

"""
Goal - find the unique

In - array 
Out - int

Assumption - 


Testcase-
[1,2,3,1,2,3,4], 4
[1,1,1,2,2,3], 3
[], -1
[3], 3

Game plan-
# loop 
# dict
# count == 1 
# return value

"""

def unique_num(arr):
  unique_dict = {}
  for x in arr:
    if x in unique_dict:
      unique_dict[x] += 1
    else:
      unique_dict[x] = 1
  
  for key,value in unique_dict.items():
    if value == 1:
      return key


# arr = [1,2,3,1,2,3,4]
# arr = [3]
# arr = []
print(unique_num(arr))



Given a 32-bit signed integer, reverse digits of an integer.

1234


4321


What happens when you visit a web site in browsers and how does browser loads the website -i.e. www.cnn.com


GET https://stackoverflow.com/api/v1/questions

[{
  "id": "str"
  "question": "str"
  "category": "str"
  "created": ""
  "user":
    {
      
    }
  "comment":
    {
      "user":{
        "created"
      }
    },
  {
  "id": "str"
  "question": "str"
  "category": "str"
  "created": ""
  "user":
    {
      
    }
  "comment":
    {
      "user":{
        "created"
      }
    },
  {
  "id": "str"
  "question": "str"
  "category": "str"
  "created": ""
  "user":
    {
      
    }
  "comment":
    {
      "user":{
        "created"
      }
    }
}]


id=2
afterdate: dec 5 



GET https://stackoverflow.com/api/v1/questions?id=2/comment
